# %%
import pandas as pd
listagem = pd.read_excel('Listagem_de_serviços-pmsl.xlsx')

# %%
listagem.head()
# Out:
#                           SECRETARIA RESPONSÁVEL       GRUPO DE SERVIÇO  \
# 0               SECRETARIA MUNICIPAL DE EDUCAÇÃO               EDUCAÇÃO
# 1                SECRETARIA MUNICIPAL DE FAZENDA                FAZENDA
# 2                SECRETARIA MUNICIPAL DE FAZENDA    ALTERAÇÃO CADASTRAL
# 3  SECRETARIA MUNICIPAL DE URBANISMO E HABITAÇÃO  URBANISMO E HABITAÇÃO
# 4                SECRETARIA MUNICIPAL DE FAZENDA                FAZENDA
#
#                                      NOME DO SERVIÇO  \
# 0          ADITIVO DE CONTRATO DE OBRAS E ENGENHARIA
# 1  ALTERAÇÃO DA INSCRIÇÃO MUNICIPAL DE MICROEMPRE...
# 2   ALTERAÇÃO DE DADOS CADASTRAIS DE PESSOA JURÍDICA
# 3            ALTERAÇÃO DE PROJETO APROVADO NA SEMURH
# 4  ALTERAÇÃO DE REGIME DE EMISSÃO DE NOTA FISCAL ...
#
#   CLIENTE DO SERVIÇO (Diga para quem esse serviços se destina)  \
# 0                                   Pessoa Jurídica.
# 1                                   Pessoa Jurídica.
# ...

# %%
listagem.columns
# Out:
# Index(['SECRETARIA RESPONSÁVEL', 'GRUPO DE SERVIÇO', 'NOME DO SERVIÇO',
#        'CLIENTE DO SERVIÇO (Diga para quem esse serviços se destina)',
#        'O QUE É O SERVIÇO (Descreva o objetivo do serviço)',
#        'DOCUMENTAÇÃO NECESSÁRIA (faça uma listagem documentação necessaria para solicitar o serviço)',
#        'LEGISLAÇÃO APLICADA', 'CANAIS E FORMAS DE COMUNICAÇÃO',
#        'PRAZO DE CONCLUSÃO DO SERVIÇO (Informe o prazo para a resposta final ou entraga do documento solicitado pelo usuário externo)',
#        'TAXAS / CUSTOS DO SERVIÇO (Informe os valores que o usurário externo deverá pagar para a a solcitação do serviço)'],
#       dtype='object')

# %%
colunas = ['SECRETARIA RESPONSÁVEL', 'GRUPO DE SERVIÇO', 'NOME DO SERVIÇO',
           'CLIENTE DO SERVIÇO (Diga para quem esse serviços se destina)',
           'O QUE É O SERVIÇO (Descreva o objetivo do serviço)',
           'DOCUMENTAÇÃO NECESSÁRIA (faça uma listagem documentação necessaria para solicitar o serviço)']

for coluna in colunas:
    listagem[coluna] = listagem[coluna].str.replace('\n',' ',regex=True)
    listagem[coluna] = listagem[coluna].str.replace('; ',';',regex=True)
    listagem[coluna] = listagem[coluna].str.replace('[()§]','',regex=True)
    listagem[coluna] = listagem[coluna].str.lstrip()

# %%
doc = 'DOCUMENTAÇÃO NECESSÁRIA (faça uma listagem documentação necessaria para solicitar o serviço)'
listagem[doc] = listagem[doc].str.replace('\n',' ',regex=True)
listagem[doc] = listagem[doc].str.replace('; ',';',regex=True)
listagem[doc] = listagem[doc].str.replace('[()§]','',regex=True)
listagem[doc] = listagem[doc].str.lstrip()

# %%
listagem[doc] = listagem[doc].str.replace('Prefeitura de São Luís','Prefeitura de São Luís;',regex=True)
listagem[doc] = listagem[doc].str.replace('Prefeitura de São Luís; ','Prefeitura de São Luís;',regex=True)
listagem[doc] = listagem[doc].str.replace('Prefeitura de São Luís ','Prefeitura de São Luís;',regex=True)
listagem[doc] = listagem[doc].str.replace('Prefeitura de São Luís;','Prefeitura de São Luís;',regex=True)
listagem[doc] = listagem[doc].str.replace('Prefeitura de São Luís;a','Prefeitura de São Luís;',regex=True)
listagem[doc] = listagem[doc].str.replace('Prefeitura de São Luís;.  ','Prefeitura de São Luís;',regex=True)
listagem[doc] = listagem[doc].str.replace('Luís;aRG/CPF','Luís;RG/CPF',regex=True)
listagem[doc] = listagem[doc].str.replace('LuíRG/CPF','Luís;RG/CPF',regex=True)
listagem[doc] = listagem[doc].str.replace(' RG/CPF','RG/CPF',regex=True)
listagem[doc] = listagem[doc].str.replace('aRG/CPF','RG/CPF',regex=True)
listagem[doc] = listagem[doc].str.replace('; ',';',regex=True)

# %%
listagem[doc] = listagem[doc].str.replace('.  a','',regex=True)
listagem[doc] = listagem[doc].str.replace('; a',';',regex=True)
listagem[doc]
# Out:
# 0      Requerimento Eletrônico;Relatório fotográfico ...
# 1      Requerimento Eletrônico;Certificado do MEI;CNP...
# 2      Requerimento Eletrônico;Ato Constitutivo;CNPJ;...
# 3      RG/CPF em caso de Pessoa Física;CNPJ em caso d...
# 4      CNPJ;Documento de Constituição da PJ;Requerime...
#                              ...
# 442    Requerimento eletrônico;Carteira Nacional de H...
# 443    Taxa Dam e Comprovante de Pagamento referente ...
# 444    Requerimento eletrônico;Sentença judicial;CRLV...
# 445    Taxa Dam e Comprovante de Pagamento referente ...
# 446    Requerimento eletrônico;CNH;Declaração por mei...
# Name: DOCUMENTAÇÃO NECESSÁRIA (faça uma listagem documentação necessaria para solicitar o serviço), Length: 447, dtype: object

# %%
listagem[doc] = listagem[doc].str.replace(';b ',';',regex=True)
listagem[doc] = listagem[doc].str.replace(';c ',';',regex=True)
# listagem[doc] = listagem[doc].str.replace(';d',';',regex=True)#

# %%
listagem['CANAIS E FORMAS DE COMUNICAÇÃO'] = listagem['CANAIS E FORMAS DE COMUNICAÇÃO'].str.replace('\n',';',regex=True)
listagem['CANAIS E FORMAS DE COMUNICAÇÃO'] = listagem['CANAIS E FORMAS DE COMUNICAÇÃO'].str.replace(': ',':',regex=True)
listagem['CANAIS E FORMAS DE COMUNICAÇÃO']
# Out:
# 0      Telefone:(98) 3212-8205;E-mail:gabinete.semed@...
# 1      WhatsApp:(98) 99136-4559;E-mail:infosemfaz@sem...
# 2      WhatsApp:(98) 99136-4559;E-mail:infosemfaz@sem...
# 3      Telefone:(98) 99120-3861;E-mail:semurh@saoluis...
# 4      WhatsApp:(98) 99136-4559;E-mail:infosemfaz@sem...
#                              ...
# 442    Telefone:(98) 99161-5632;E-mail:atendimentoccl...
# 443    Telefone:(98) 99161-5632;E-mail:atendimentoccl...
# 444    Telefone:(98) 99161-5632;E-mail:atendimentoccl...
# 445    Telefone:(98) 99161-5632;;E-mail:atendimentocc...
# 446    Telefone:(98) 99161-5632;E-mail:atendimentoccl...
# Name: CANAIS E FORMAS DE COMUNICAÇÃO, Length: 447, dtype: object

# %%
listagem['LEGISLAÇÃO APLICADA'] = listagem['LEGISLAÇÃO APLICADA'].str.lstrip()
listagem['LEGISLAÇÃO APLICADA'] = listagem['LEGISLAÇÃO APLICADA'].str.replace(': ',':',regex=True)
listagem['LEGISLAÇÃO APLICADA'] = listagem['LEGISLAÇÃO APLICADA'].str.replace('\n',';',regex=True)
listagem['LEGISLAÇÃO APLICADA']
# Out:
# 0      Lei N° 1.847 de 10 de janeiro de 1996 - Que in...
# 1      Lei n° 6.289, de 28 de dezembro de 2017 – “Ins...
# 2      Lei n° 6.289, de 28 de dezembro de 2017 – “Ins...
# 3         Lei Municipal nº 3.902, de 13 de maio de 2000.
# 4      Lei Municipal n° 6.949 de 30 de dezembro de 2021.
#                              ...
# 442    Lei nº 6.292, de 28 de dezembro de 2017 - inst...
# 443    Lei nº 6.292, de 28 de dezembro de 2017 - inst...
# 444    Lei nº 6.292, de 28 de dezembro de 2017 - inst...
# 445    Lei nº 6.292, de 28 de dezembro de 2017 - inst...
# 446    Lei nº 6.292, de 28 de dezembro de 2017 - inst...
# Name: LEGISLAÇÃO APLICADA, Length: 447, dtype: object

# %%
listagem.head(30)
# Out:
#                             SECRETARIA RESPONSÁVEL        GRUPO DE SERVIÇO  \
# 0                 SECRETARIA MUNICIPAL DE EDUCAÇÃO                EDUCAÇÃO
# 1                  SECRETARIA MUNICIPAL DE FAZENDA                 FAZENDA
# 2                  SECRETARIA MUNICIPAL DE FAZENDA     ALTERAÇÃO CADASTRAL
# 3    SECRETARIA MUNICIPAL DE URBANISMO E HABITAÇÃO   URBANISMO E HABITAÇÃO
# 4                  SECRETARIA MUNICIPAL DE FAZENDA                 FAZENDA
# 5                  SECRETARIA MUNICIPAL DE FAZENDA     ALTERAÇÃO CADASTRAL
# 6    SECRETARIA MUNICIPAL DE URBANISMO E HABITAÇÃO   URBANISMO E HABITAÇÃO
# 7    SECRETARIA MUNICIPAL DE URBANISMO E HABITAÇÃO   URBANISMO E HABITAÇÃO
# 8    SECRETARIA MUNICIPAL DE URBANISMO E HABITAÇÃO   URBANISMO E HABITAÇÃO
# 9    SECRETARIA MUNICIPAL DE URBANISMO E HABITAÇÃO   URBANISMO E HABITAÇÃO
# 10   SECRETARIA MUNICIPAL DE URBANISMO E HABITAÇÃO   URBANISMO E HABITAÇÃO
# ...

# %%
listagem.to_excel('documentação-tratada3.xlsx', index=False)
